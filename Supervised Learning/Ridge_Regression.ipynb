# %% [markdown]
# <a href="https://colab.research.google.com/github/thatadi/cuddly-lamp/blob/main/Supervised%20Learning/Ridge_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(42)
n_samples = 100
X1 = np.random.randn(n_samples)
X2 = 0.8 * X1 + np.random.randn(n_samples) * 0.2
X = np.column_stack([X1, X2])

# %%
Y = 3 * X1 + 2 * X2 + np.random.randn(n_samples) * 0.5

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
ridge_reg = Ridge(alpha=1)

# %%
ridge_reg.fit(X_train, Y_train)
# Out:
# Ridge(alpha=1)

# %%
Y_pred = ridge_reg.predict(X_test)

# %%
plt.scatter(Y_test, Y_pred)
plt.plot([Y.min(), Y.max()], [Y.min(), Y.max()], '--r')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Ridge Regression: Actual vs. Predicted")
plt.show()

# %%
plt.scatter(Y_test, Y_pred)
plt.plot([Y.min(), Y.max()], [Y.min(), Y.max()], '--r')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Ridge Regression: Actual vs. Predicted")
plt.show()
